# %%
import os
from src.crew import create_crew

# Ensure you have your Google API Key set
# os.environ["GOOGLE_API_KEY"] = "AIzaSy..."
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from src.crew import create_crew
#       4 # Ensure you have your Google API Key set
#       5 # os.environ["GOOGLE_API_KEY"] = "AIzaSy..."
#
# ModuleNotFoundError: No module named 'src'

# %%
crew = create_crew()
print("Crew created successfully!")

# %%
# Example Query
query = "cancer therapy" 
result = crew.kickoff(inputs={'topic': query})
print(result)
